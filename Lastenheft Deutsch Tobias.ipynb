# %% [markdown]
# Jira und Projektplanung nicht seperat eingebracht, wenn es nicht als Gruppe geschehen ist: zu viele zu kleine Zeitabschnitte dafür aufgewendet.
#
# ### Vorher
# November-Dezember: Beginn Projektplanung, Idee (HPI)
# Januar-Februar: Voice-Calls zur genaueren Projektplanung, Vorbereitung Unity-Projekt von Jannis K.
#
# ### 28.02. - 3:30h Tobias
# - Grundlegendes Hauptmenü
# - fast nur Recherche und Unity/C# ausprobieren
# - TODO (/Problem): Buttons und Text zumeist stark verschwommen (teilweise gelöst (mit Hilfe/Infos von Jannis K.), 02.03.)
#
# ### 01.03. - 3:45 Tobias
# - grundlegendes Inventar (UI) designt
# - öffnet sich auf Knopfdruck "I"
# - beherrsche Unity - UI und Sprites - eigenlich ganz gut
#
# ### 02.03. - 3:00 Tobias
# - Inventardesign abgeschlossen + Hotbar hinzugefügt
# - Arbeit an Pausenmenü begonnen
# - Arbeit an GameManager begonnen (17.03. - bis jetzt nicht fortgesetzt)
#     - sollte alles was Input angeht + das Unity EventSystem organisieren
#     - anhand von Game-States (isPaused, levelID, ...)
#
# ### 04.03. - 2:00 Tobias
# - größtes Problem bisher: Modularität
#     - verschiedene Module (Pausenmenü, Inventar, UI) in verschiedene Szenen, die einzeln in die RAM geladen/entladen werden können
#         - gut für Skalierbarkeit, gegen Ladebildschirme, man muss aber darauf achten, dass wichtige Szenen nicht permanent entladen werden, um den Speicher nicht unnötig zu belasten - das ist etwas gewöhnungsbedürftig
#     - Unity kann (z.B.) Skripts die passenden Variablen und Objekte nicht über Szenen hinweg zugewiesen werden können, muss manuell mit C# gemacht werden (17.03., immer noch größtes eigenes Problem, aber Git ist gefährlicher fürs Projekt)
# - dennoch Resume-Button über die Szenen hinweg verbunden (zuerst noch mit dem GameManager)
# - dementsprechend etwas Arbeit daran
# - ein wenig Co-working mit Jannis N.
#
# ### 04.03. - 01:00 Jannis K., Tobias
# - fast nur Co-working, am Ende alleine Git etwas aufgeräumt (eigentlich sinnlos)
# - Git-Branches gemerged -> erste Probleme damit aufgetreten
# - dann noch zwischendurch versucht eine Minimap hinzuzufügen (hat auch erstmal geklappt, ist aber irgendwann verlorengegangen, 15-17.03. eine neue, auch von Jannis K.)
#     - dabei viele Merge-Conflicts aufgetreten
#     - $\rightarrow$ klare Trennung von Projektarbeit und Git-Arbeit
# ![][def]
#
# [def]: git-disaster.png
# ein Bild von dem verworrenen Zwischenstand unseres Git-Graphes nachdem wir alles behoben hatten
# Sollte aufgrund der Formatierung des Links im selben Ordner platziert werden, wie das .ipynb
#
# ### 05.03. - 1:00 Tobias + Grundschüler
# Die englische Originaldokumentation hiervon ist irgendwann verlorengegangen, neuschreiben ist aber schneller als suchen.
# - habe das Projekt als Beschäftigung + Computerkompetenzlehre für zwei Viertklässler genutzt
# - habe beigebracht Tilemaps zu bearbeiten, daraufhin den Hintergrund des Hauptmenü editieren lassen (besser als vorher)
# - im Gespräch auf gute Ideen gebracht worden, z.B. Kamerabewegung im Hauptmenü
#     - auf Jira eingebracht
#
# ### 11.03. - 1:20 Tobias
# - alle kleineren Probleme mit dem Pausenmenü repariert (Kompatibilität)
# - erfolgreich Fortschritt auf den dev-Branch gemerged
#     - danach aber manchmal Ladebildschirme bzw. Blackscreens (keine Kamera (in der Szene), weil keine Szene) beim Szenenwechsel
#
# ### 12.03. - 3:30 Tobias
# - Arbeit an Inventarlogik begonnen
#     - Problem: viele sehr ähnliche (z.T. gleiche) Namen, auch wegen der Modularität $\rightarrow$ Skripts werden ziemlich unübersichtlich
#     - Problem2 (reine Modularität): Objektzuweisung und Variablen für C# Skripte manuell
#         - beim Debuggen sogar ChatGPT mit vollem Datenaustausch hinzugezogen, hat aber nichts gebracht
#
# ### 13.03. - 2:10 Tobias
# - Problem2 von gestern war nach etwas Schlaf eigentlich ganz einfach:
#     - ich habe versucht "Text" von einem GameObject zu beschreiben, habe aber in Unity TextMeshPro benutzt $\rightarrow$ "TMP_Text"
# - daraufhin noch Items hinzugefügt/korrigiert
#     - kann man sogar schon aufheben (Kollisionen) und ins Inventar übertragen
#
# ### 14.03. - 2:30 Tobias
# - versucht Inventar im Spiel zu benutzen und Items zu verschieben
#     - momentan davon abgekommen, wegen Zeitmangel und Krankheit
# - Kompatibilität für ein maximales Stacklimit hinzugefügt + Items sind überhaupt erst stackable
#
# ### Irgendwann dazwischen: Tobias
# weiß nicht mehr wie lange oder wann, war krank dabei (habe deshalb auch vergessen zu dokumentieren)
# -
#
# ### 17.03. - 2:00 Jannis N., Jannis K., Tobias
# - zusammen besprochen, was an welchem Tag fertig sein soll und wie man was abgibt und vorstellt
# - dann noch mit Jannis K. ein paar Git-Branches gemerged, jeder alleine beendet
